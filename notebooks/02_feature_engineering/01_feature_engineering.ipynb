# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../../data/interim/data_cleaned.csv", parse_dates=["date"])

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df["year"] = df["date"].dt.year
df["month"] = df["date"].dt.month
df["day"] = df["date"].dt.day

# %%
df["age_at_sale"] = df["year"] - df["yr_built"]
df["was_renovated"] = df["yr_renovated"].apply(lambda x: 1 if x > 0 else 0)
df["years_since_renovation"] = df.apply(lambda x: x["year"] - x["yr_renovated"] if x["yr_renovated"] > 0 else 0 , axis=1)
df["total_sqft"] = df["sqft_living"] + df["sqft_basement"]

# %%
cols_to_drop = [
    'date',          
    'year',          
    'street',        
    'statezip',      
    'country',       
    'yr_built',     
    'yr_renovated',   
]
df.drop(columns=cols_to_drop, inplace=True)

# %%
df.corr(numeric_only=True)
# Out:
#                            price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# price                   1.000000  0.360944   0.544772     0.697821  0.167702
# bedrooms                0.360944  1.000000   0.545645     0.616620  0.207344
# bathrooms               0.544772  0.545645   1.000000     0.752544  0.147447
# sqft_living             0.697821  0.616620   0.752544     1.000000  0.366745
# sqft_lot                0.167702  0.207344   0.147447     0.366745  1.000000
# floors                  0.295128  0.180860   0.493975     0.355040 -0.165792
# waterfront              0.130780 -0.005673   0.063318     0.076278  0.105332
# view                    0.345696  0.117163   0.207231     0.285592  0.129167
# condition               0.058628  0.021990  -0.121796    -0.061669  0.042342
# sqft_above              0.600700  0.496975   0.684060     0.868319  0.349107
# sqft_basement           0.308155  0.335067   0.295543     0.414831  0.101613
# ...

# %%
df.head(2)
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0        1.5         1340      7912     1.5           0
# 1  1154600.0       5.0        2.5         3650      9050     2.0           0
#
#    view  condition  sqft_above  sqft_basement       city  month  day  \
# 0     0          3        1340              0  Shoreline      5    2
# 1     4          5        3370            280    Seattle      5    2
#
#    age_at_sale  was_renovated  years_since_renovation  total_sqft
# 0           59              1                       9        1340
# 1           93              0                       0        3930

# %%
print("Final shape:", df.shape)
print("Final columns:", df.columns.tolist())
# Out:
# Final shape: (4549, 18)
# Final columns: ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement', 'city', 'month', 'day', 'age_at_sale', 'was_renovated', 'years_since_renovation', 'total_sqft']

# %%
import os
os.makedirs("../../data/interim", exist_ok=True)

# Save engineered data
df.to_csv("../../data/interim/data_engineered.csv", index=False)
print("Data saved to data/interim/data_engineered.csv")
# Out:
# Data saved to data/interim/data_engineered.csv
